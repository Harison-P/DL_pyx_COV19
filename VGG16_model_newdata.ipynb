# %%
import numpy as np 
import pandas as pd 
import cv2 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import re
import random
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
import keras
from keras import backend as K
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras import layers
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Activation, Add, ReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.metrics import Recall, Precision, AUC
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adadelta, Adam, SGD
from keras.regularizers import l2
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import load_model
import itertools
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data visualization

# %% [markdown]
# > We plot randomly chosen pictures from each label.

# %%
def data_viz(path):
    # Create a matplotlib figure
    fig, axes = plt.subplots(nrows = 1, ncols = 3, sharex = True, sharey = True, figsize = (16, 16))
    ax = axes.ravel()
    
    # Browse files in the path directory
    full_path = glob.glob(path+'/*/*.png')
    
    # Get class labels
    class_name = list(set([re.findall(r'([\w\s-]+)', i)[-4] for i in full_path]))
    
    # Define COVID image
    class_covid = [s for s in full_path if '/' + class_name[0] + '/' in s]
    covid_random_index = np.random.choice(np.arange(0, len(class_covid)), size = 1)[0]
    covid_random_img = cv2.imread(class_covid[covid_random_index])
    covid_random_img = cv2.cvtColor(covid_random_img, cv2.COLOR_BGR2GRAY)
    covid_random_img = cv2.resize(covid_random_img, (224, 224))
    
    # Define NORMAL image
    class_normal = [s for s in full_path if '/' + class_name[1] + '/' in s]
    normal_random_index = np.random.choice(np.arange(0, len(class_normal)), size = 1)[0]
    normal_random_img = cv2.imread(class_normal[normal_random_index])
    normal_random_img = cv2.cvtColor(normal_random_img, cv2.COLOR_BGR2GRAY)
    normal_random_img = cv2.resize(normal_random_img, (224, 224))
    
    # Define Viral Pneumonia image
    class_viral = [s for s in full_path if '/' + class_name[2] + '/' in s]
    viral_random_index = np.random.choice(np.arange(0, len(class_viral)), size = 1)[0]
    viral_random_img = cv2.imread(class_viral[viral_random_index])
    viral_random_img = cv2.cvtColor(viral_random_img, cv2.COLOR_BGR2GRAY)
    viral_random_img = cv2.resize(viral_random_img, (224, 224))
    
    # Plot images
    ax[0].imshow(covid_random_img, cmap=plt.cm.gray)
    ax[0].set_title('COVID-19')
    
    ax[1].imshow(normal_random_img, cmap=plt.cm.gray)
    ax[1].set_title('Normal')
    
    ax[2].imshow(viral_random_img, cmap=plt.cm.gray)
    ax[2].set_title('Viral Pneumonia')
    
    for a in ax:
        a.axis('off')

# %%
data_viz(path = '/content/drive/MyDrive/COVID-19 Radiography Database')

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Building a dataframe

# %% [markdown]
# > We build a dataframe containing the image filepaths and their corresponding label.

# %%
# find all the files with the PNG extension
full_path = glob.glob('/content/drive/MyDrive/COVID-19 Radiography Database/*/*.png')
# extract the image label
class_name = [re.findall(r'([\w\s-]+)', i)[-4] for i in full_path]
# Build a dataframe
df = pd.DataFrame(data = np.stack([np.array(full_path), np.array(class_name)], axis = 1), columns = ['img_paths', 'label'])
df.head()
# Out:
#                                            img_paths     label
# 0  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19
# 1  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19
# 2  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19
# 3  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19
# 4  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19

# %% [markdown]
# ## Train / Test split

# %% [markdown]
# > The data will be split into two parts :
# >- Training set : 80%
# >- Test set : 20%

# %%
df_train, df_test = train_test_split(df,
                                     test_size = 0.2,
                                     stratify = df.label,
                                     random_state = 42)

# %%
print('Training data shape:', df_train.shape)
print('Test data shape:', df_test.shape)
# Out:
# Training data shape: (3063, 2)
# Test data shape: (766, 2)

# %%
print('Normal images count in training set:', df_train.img_paths.str.contains('NORMAL').sum())
print('COVID-19 images count in training set:', df_train.img_paths.str.contains('/COVID-19/').sum())
print('Viral Pneumonia images count in training set:', df_train.img_paths.str.contains('Viral Pneumonia').sum())
# Out:
# Normal images count in training set: 1073
# COVID-19 images count in training set: 914
# Viral Pneumonia images count in training set: 1076

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# > Data augmentation is a method often applied in Deep Learning to generate a number of samples required.
# >
# > It enhances the effectiveness of the neural network for a small databases by optimizing it.
# >
# > Furthemore, our dataset is imbalanced, so applying some image augmentation techniques will aim to artificially increase the size of the training data.

# %%
datagen_train = ImageDataGenerator(rescale = 1./255.,
                                   rotation_range = 10,
                                   zoom_range = [0.9, 1.1],
                                   width_shift_range = [-0.1, 0.1],
                                   height_shift_range = [-0.1, 0.1],
                                   horizontal_flip = True)

datagen_val = ImageDataGenerator(rescale = 1./255.,
                                 rotation_range = 10,
                                 zoom_range = [0.9, 1.1],
                                 width_shift_range = [-0.1, 0.1],
                                 height_shift_range = [-0.1, 0.1])

# %%
train_generator = datagen_train.flow_from_dataframe(dataframe = df_train,
                                                    directory = None,
                                                    x_col = 'img_paths',
                                                    y_col = 'label',
                                                    class_mode = 'categorical',
                                                    batch_size = 32,
                                                    shuffle = False,
                                                    subset = 'training')

test_generator = datagen_val.flow_from_dataframe(dataframe = df_test,
                                                 directory = None,
                                                 x_col = 'img_paths',
                                                 y_col = 'label',
                                                 class_mode = 'categorical',
                                                 batch_size = 32,
                                                 shuffle = False)
# Out:
# Found 3063 validated image filenames belonging to 3 classes.
# Found 766 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Model Building

# %%
batch_size = 32
learning_rate = 0.001

# %% [markdown]
# ## Custom metrics

# %% [markdown]
# > We define the F1-score metric by defining the recall and precision metric function.

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
METRICS = ['accuracy', AUC(name = 'auc'), f1_m]

# %% [markdown]
# ## Architecture

# %% [markdown]
# > Our model is built using the transfer learning technique.
# > The base model is a pre-trained VGG16 model on ImageNet and the classification part consists of three Dense layers with ReLU activation layer followed by a Dropout layer for regularization with a rate of 0.5.
# > Finally, the output layer consists of 3 neurons, each neuron for a class, and a softmax activation function.

# %%
num_classes = 3

base_model = VGG16(
    include_top = False, # Do not include the ImageNet classifier at the top.
    weights = "imagenet", # Load weights pre-trained on ImageNet.
    input_shape = (224, 224, 3)
)

# Freeze the base_model
base_model.trainable = False

output_model = base_model.output
output_model = GlobalAveragePooling2D()(output_model)
output_model = Flatten()(output_model)
output_model = Dense(256, activation = 'relu')(output_model) #adding a new dense 256 layer w/ a .5 dropout
output_model = Dropout(0.5)(output_model)
output_model = Dense(128, activation = 'relu')(output_model) #adding a new dense 128 layer w/ a .5 dropout
output_model = Dropout(0.5)(output_model)
output_model = Dense(64, activation = 'relu')(output_model)
output_model = Dropout(0.5)(output_model)
output_model = Dense(num_classes, activation = 'softmax', name = 'visualized_layer')(output_model)

final_model = Model(inputs = base_model.input, outputs = output_model)

final_model.compile(optimizer = Adam(lr = learning_rate),
                    loss = 'categorical_crossentropy',
                    metrics = METRICS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
final_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# visualized_layer (Dense)     (None, 3)                 195
# =================================================================
# Total params: 14,887,363
# Trainable params: 172,675
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Fitting the model

# %% [markdown]
# > We define class weights (as we did on the initial data) to put more emphasis on the slightly imbalanced class during the training phase.

# %%
covid_19_count = df[df.label == 'COVID-19'].shape[0]
normal_count = df[df.label == 'NORMAL'].shape[0]
viral_count = df[df.label == 'Viral'].shape[0]

print('COVID-19 images count', covid_19_count)
print('NORMAL images count', normal_count)
print('Viral Pneumonia images count', viral_count)
# Out:
# COVID-19 images count 1143
# NORMAL images count 1341
# Viral Pneumonia images count 1345

# %%
total_wt = df.shape[0]

weights = {
    0: 0.5 * (1 - covid_19_count/total_wt),
    1: 0.5 * (1 - normal_count/total_wt),
    2: 0.5 * (1 - viral_count/total_wt)
}
print(weights)
# Out:
# {0: 0.35074431966570907, 1: 0.32488900496213113, 2: 0.3243666753721598}

# %%
history = final_model.fit_generator(generator = train_generator,
                                    class_weight = weights,
                                    steps_per_epoch = df_train.shape[0] // batch_size,
                                    validation_data = test_generator,
                                    validation_steps = df_test.shape[0] // batch_size,
                                    epochs = 20)
# Out:
# Epoch 1/20
# 95/95 [==============================] - 805s 8s/step - loss: 0.3872 - accuracy: 0.3761 - auc: 0.5503 - f1_m: 0.1851 - val_loss: 0.8547 - val_accuracy: 0.6128 - val_auc: 0.8570 - val_f1_m: 0.5835
# Epoch 2/20
# 95/95 [==============================] - 97s 1s/step - loss: 0.2721 - accuracy: 0.6308 - auc: 0.8146 - f1_m: 0.5177 - val_loss: 0.4618 - val_accuracy: 0.8465 - val_auc: 0.9457 - val_f1_m: 0.8368
# Epoch 3/20
# 95/95 [==============================] - 96s 1s/step - loss: 0.1717 - accuracy: 0.8106 - auc: 0.9290 - f1_m: 0.7962 - val_loss: 0.3612 - val_accuracy: 0.8668 - val_auc: 0.9624 - val_f1_m: 0.8683
# Epoch 4/20
# 95/95 [==============================] - 98s 1s/step - loss: 0.1348 - accuracy: 0.8626 - auc: 0.9552 - f1_m: 0.8570 - val_loss: 0.2983 - val_accuracy: 0.8913 - val_auc: 0.9747 - val_f1_m: 0.8892
# Epoch 5/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.1175 - accuracy: 0.8873 - auc: 0.9639 - f1_m: 0.8832 - val_loss: 0.2638 - val_accuracy: 0.9076 - val_auc: 0.9793 - val_f1_m: 0.9093
# Epoch 6/20
# 95/95 [==============================] - 100s 1s/step - loss: 0.1048 - accuracy: 0.8988 - auc: 0.9713 - f1_m: 0.8967 - val_loss: 0.2536 - val_accuracy: 0.9130 - val_auc: 0.9806 - val_f1_m: 0.9134
# Epoch 7/20
# 95/95 [==============================] - 100s 1s/step - loss: 0.1076 - accuracy: 0.8942 - auc: 0.9692 - f1_m: 0.8922 - val_loss: 0.2244 - val_accuracy: 0.9198 - val_auc: 0.9851 - val_f1_m: 0.9206
# Epoch 8/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.0944 - accuracy: 0.9070 - auc: 0.9759 - f1_m: 0.9074 - val_loss: 0.2666 - val_accuracy: 0.8927 - val_auc: 0.9790 - val_f1_m: 0.8986
# Epoch 9/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.0905 - accuracy: 0.9082 - auc: 0.9774 - f1_m: 0.9087 - val_loss: 0.2286 - val_accuracy: 0.9158 - val_auc: 0.9846 - val_f1_m: 0.9176
# Epoch 10/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.0787 - accuracy: 0.9233 - auc: 0.9823 - f1_m: 0.9241 - val_loss: 0.2218 - val_accuracy: 0.9212 - val_auc: 0.9855 - val_f1_m: 0.9198
# Epoch 11/20
# 95/95 [==============================] - 98s 1s/step - loss: 0.0926 - accuracy: 0.9147 - auc: 0.9768 - f1_m: 0.9111 - val_loss: 0.2314 - val_accuracy: 0.9144 - val_auc: 0.9842 - val_f1_m: 0.9117
# Epoch 12/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.0820 - accuracy: 0.9210 - auc: 0.9813 - f1_m: 0.9212 - val_loss: 0.2043 - val_accuracy: 0.9266 - val_auc: 0.9868 - val_f1_m: 0.9279
# Epoch 13/20
# 95/95 [==============================] - 98s 1s/step - loss: 0.0842 - accuracy: 0.9190 - auc: 0.9806 - f1_m: 0.9178 - val_loss: 0.2271 - val_accuracy: 0.9212 - val_auc: 0.9832 - val_f1_m: 0.9230
# Epoch 14/20
# 95/95 [==============================] - 98s 1s/step - loss: 0.0807 - accuracy: 0.9205 - auc: 0.9816 - f1_m: 0.9220 - val_loss: 0.2049 - val_accuracy: 0.9280 - val_auc: 0.9861 - val_f1_m: 0.9277
# Epoch 15/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.0895 - accuracy: 0.9162 - auc: 0.9789 - f1_m: 0.9152 - val_loss: 0.2140 - val_accuracy: 0.9226 - val_auc: 0.9871 - val_f1_m: 0.9222
# Epoch 16/20
# 95/95 [==============================] - 102s 1s/step - loss: 0.0835 - accuracy: 0.9182 - auc: 0.9802 - f1_m: 0.9180 - val_loss: 0.2286 - val_accuracy: 0.9212 - val_auc: 0.9848 - val_f1_m: 0.9223
# Epoch 17/20
# 95/95 [==============================] - 100s 1s/step - loss: 0.0761 - accuracy: 0.9298 - auc: 0.9826 - f1_m: 0.9303 - val_loss: 0.1948 - val_accuracy: 0.9361 - val_auc: 0.9885 - val_f1_m: 0.9346
# Epoch 18/20
# 95/95 [==============================] - 100s 1s/step - loss: 0.0667 - accuracy: 0.9402 - auc: 0.9863 - f1_m: 0.9412 - val_loss: 0.2094 - val_accuracy: 0.9280 - val_auc: 0.9870 - val_f1_m: 0.9258
# Epoch 19/20
# 95/95 [==============================] - 99s 1s/step - loss: 0.0858 - accuracy: 0.9180 - auc: 0.9798 - f1_m: 0.9167 - val_loss: 0.1947 - val_accuracy: 0.9280 - val_auc: 0.9887 - val_f1_m: 0.9284
# Epoch 20/20
# 95/95 [==============================] - 95s 1000ms/step - loss: 0.0838 - accuracy: 0.9214 - auc: 0.9797 - f1_m: 0.9191 - val_loss: 0.1902 - val_accuracy: 0.9402 - val_auc: 0.9875 - val_f1_m: 0.9408

# %% [markdown]
# # Evaluation of the model

# %% [markdown]
# > We define two functions for evaluating the model.
# >
# >\
# > The `display_history` function enables to plot the loss function, the accuracy, the f1_score and the AUC for the training and validation set. Its only argument is the history of the model.
# >
# >\
# > The `plot_confusion_matrix` function enables to plot a beautiful version of the confusion matrix with a heatmap. Its main arguments are :
# > - cm : confusion matrix
# > - classes : the class labels (COVID-19, Normal, Viral Pneumonia)
# >
# > The output is a normalized confusion matrix regarding the recalls. In other words, only the recalls for each class is shown.

# %%
def display_history(history_):
    fig, ax = plt.subplots(1, 4, figsize = (20, 10))
    ax[0].plot(history_.history['loss'], color = 'b', label = "training_loss")
    ax[0].plot(history_.history['val_loss'], color = 'r', label = "validation_loss", axes = ax[0])
    legend = ax[0].legend(loc = 'best', shadow = True)

    ax[1].plot(history_.history['accuracy'], color = 'b', label = "training_accuracy")
    ax[1].plot(history_.history['val_accuracy'], color = 'r', label = "validation_accuracy")
    legend = ax[1].legend(loc = 'best', shadow = True)

    ax[2].plot(history_.history['f1_m'], color = 'b', label = "training_f1_score")
    ax[2].plot(history_.history['val_f1_m'], color = 'r', label = "validation_f1_score")
    legend = ax[2].legend(loc = 'best', shadow = True)

    ax[3].plot(history_.history['auc'], color = 'b', label = "training_auc")
    ax[3].plot(history_.history['val_auc'], color = 'r', label = "validation_auc")
    legend = ax[3].legend(loc = 'best', shadow = True)

# %%
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
results = final_model.evaluate_generator(generator = test_generator, steps = df_test.shape[0] // batch_size)
for index, metric in enumerate(final_model.metrics_names):
  print(f'test_{metric} :',round(results[index]*100),'%')
# Out:
# test_loss : 18 %
# test_accuracy : 94 %
# test_auc : 99 %
# test_f1_m : 94 %

# %%
display_history(history)

# %% [markdown]
# ## Confusion matrix

# %%
test_generator.reset() # the reset method allows us to not get the outputs in disorder
predictions = final_model.predict_generator(generator = test_generator)
y_test = test_generator.classes
y_pred = np.argmax(predictions, axis = -1)
class_names = test_generator.class_indices.keys()

# %% [markdown]
# > The `y_pred` array contains the predicted labels but since they are encoded, we can't tell which predicted encoded label corresponds to its predicted original (*categorical*) label.
# >
# > In the following cell, the `final_predictions` list maps the predicted labels with their uniques ID's (*i.e.* filenames `img_paths`).

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
final_predictions = [labels[k] for k in y_pred]

filenames = test_generator.filenames
results = pd.DataFrame({"img_paths":filenames,
                      "Predictions":final_predictions})

# %% [markdown]
# > We build a dataframe `results` that associates the predicted label to the image.

# %%
results.head()
# Out:
#                                            img_paths Predictions
# 0  /content/drive/MyDrive/COVID-19 Radiography Da...       Viral
# 1  /content/drive/MyDrive/COVID-19 Radiography Da...    COVID-19
# 2  /content/drive/MyDrive/COVID-19 Radiography Da...      NORMAL
# 3  /content/drive/MyDrive/COVID-19 Radiography Da...    COVID-19
# 4  /content/drive/MyDrive/COVID-19 Radiography Da...    COVID-19

# %%
final_df_labels = df_test.merge(results, on = 'img_paths')
final_df_labels.head()
# Out:
#                                            img_paths     label Predictions
# 0  /content/drive/MyDrive/COVID-19 Radiography Da...     Viral       Viral
# 1  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19    COVID-19
# 2  /content/drive/MyDrive/COVID-19 Radiography Da...    NORMAL      NORMAL
# 3  /content/drive/MyDrive/COVID-19 Radiography Da...     Viral    COVID-19
# 4  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19    COVID-19

# %% [markdown]
# > The `final_df_labels` is a merge between the `df_test` DataFrame with the ground truth labels and the `results` DataFrame with the predicted labels.

# %%
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# %%
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, title = 'Normalized confusion matrix')
plt.show();

# %% [markdown]
# > This normalized confusion matrix represents the recalls of each category.
# >
# > As one can see, on the one hand the recalls for COVID-19 and Normal categories are almost perfect (respectively 96% and 93%), on the other hand the Viral Pneumonial category needs some improving since 9% of Viral Pneumonia images are predicted as Normal.

# %% [markdown]
# ## Classification report

# %%
print(classification_report(y_test, y_pred, target_names = class_names))
# Out:
#               precision    recall  f1-score   support
#
#     COVID-19       0.96      0.96      0.96       229
#       NORMAL       0.93      0.93      0.93       268
#        Viral       0.91      0.91      0.91       269
#
#     accuracy                           0.93       766
#    macro avg       0.93      0.93      0.93       766
# weighted avg       0.93      0.93      0.93       766

# %% [markdown]
# > The recalls for COVID-19 and Normal are higher than precision which is exactly what we would want because, in the medical field, we strive for getting the number of False Negatives as low as possible.
# >
# > Note that the f1-score for each category is greater than 90% which is a good result.

# %% [markdown]
# # Fine-tuning

# %% [markdown]
# ## Architecture

# %%
# We let the model train the 10 last layers of the VGG16 models
for layer in base_model.layers[-10:]:
    layer.trainable = True

# %%
# The 'lr_plateau' callback enables to change the learning_rate with respect to the accuracy metric on the test set
lr_plateau = ReduceLROnPlateau(monitor = 'val_loss',
                               patience = 10,
                               verbose = 2,
                               mode = 'min')

# %%
# Let's run again the model, decreasing the learning rate
final_model.compile(optimizer = Adam(lr = learning_rate/10),
                    loss = 'categorical_crossentropy',
                    metrics = METRICS)

# %% [markdown]
# ## Fitting the fine-tuned model

# %%
finetuned_history = final_model.fit_generator(generator = train_generator,
                                              class_weight = weights,
                                              steps_per_epoch = df_train.shape[0] // batch_size,
                                              validation_data = test_generator,
                                              validation_steps = df_test.shape[0] // batch_size,
                                              epochs = 30,
                                              callbacks = [lr_plateau])
# Out:
# Epoch 1/30
# 95/95 [==============================] - 100s 1s/step - loss: 0.6528 - accuracy: 0.5385 - auc: 0.8505 - f1_m: 0.5206 - val_loss: 0.4989 - val_accuracy: 0.7853 - val_auc: 0.9355 - val_f1_m: 0.7871
# Epoch 2/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.1606 - accuracy: 0.8292 - auc: 0.9388 - f1_m: 0.8242 - val_loss: 0.2964 - val_accuracy: 0.8967 - val_auc: 0.9765 - val_f1_m: 0.8936
# Epoch 3/30
# 95/95 [==============================] - 99s 1s/step - loss: 0.1188 - accuracy: 0.8727 - auc: 0.9648 - f1_m: 0.8719 - val_loss: 0.2534 - val_accuracy: 0.9076 - val_auc: 0.9833 - val_f1_m: 0.9069
# Epoch 4/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0912 - accuracy: 0.9131 - auc: 0.9780 - f1_m: 0.9122 - val_loss: 0.3084 - val_accuracy: 0.8995 - val_auc: 0.9744 - val_f1_m: 0.8961
# Epoch 5/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0829 - accuracy: 0.9147 - auc: 0.9817 - f1_m: 0.9142 - val_loss: 0.1732 - val_accuracy: 0.9361 - val_auc: 0.9904 - val_f1_m: 0.9353
# Epoch 6/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0721 - accuracy: 0.9307 - auc: 0.9855 - f1_m: 0.9320 - val_loss: 0.2456 - val_accuracy: 0.9144 - val_auc: 0.9843 - val_f1_m: 0.9160
# Epoch 7/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0756 - accuracy: 0.9237 - auc: 0.9840 - f1_m: 0.9242 - val_loss: 0.1596 - val_accuracy: 0.9497 - val_auc: 0.9898 - val_f1_m: 0.9490
# Epoch 8/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0603 - accuracy: 0.9376 - auc: 0.9895 - f1_m: 0.9384 - val_loss: 0.1970 - val_accuracy: 0.9361 - val_auc: 0.9889 - val_f1_m: 0.9364
# Epoch 9/30
# 95/95 [==============================] - 103s 1s/step - loss: 0.0600 - accuracy: 0.9430 - auc: 0.9895 - f1_m: 0.9421 - val_loss: 0.1760 - val_accuracy: 0.9470 - val_auc: 0.9897 - val_f1_m: 0.9439
# Epoch 10/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0621 - accuracy: 0.9509 - auc: 0.9885 - f1_m: 0.9484 - val_loss: 0.1056 - val_accuracy: 0.9620 - val_auc: 0.9967 - val_f1_m: 0.9620
# Epoch 11/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0480 - accuracy: 0.9481 - auc: 0.9927 - f1_m: 0.9487 - val_loss: 0.0971 - val_accuracy: 0.9674 - val_auc: 0.9964 - val_f1_m: 0.9646
# Epoch 12/30
# 95/95 [==============================] - 103s 1s/step - loss: 0.0397 - accuracy: 0.9634 - auc: 0.9940 - f1_m: 0.9634 - val_loss: 0.1473 - val_accuracy: 0.9470 - val_auc: 0.9940 - val_f1_m: 0.9470
# Epoch 13/30
# 95/95 [==============================] - 103s 1s/step - loss: 0.0417 - accuracy: 0.9630 - auc: 0.9938 - f1_m: 0.9618 - val_loss: 0.1517 - val_accuracy: 0.9484 - val_auc: 0.9943 - val_f1_m: 0.9469
# Epoch 14/30
# 95/95 [==============================] - 104s 1s/step - loss: 0.0390 - accuracy: 0.9619 - auc: 0.9942 - f1_m: 0.9603 - val_loss: 0.0911 - val_accuracy: 0.9688 - val_auc: 0.9966 - val_f1_m: 0.9693
# Epoch 15/30
# 95/95 [==============================] - 103s 1s/step - loss: 0.0424 - accuracy: 0.9583 - auc: 0.9945 - f1_m: 0.9588 - val_loss: 0.1110 - val_accuracy: 0.9660 - val_auc: 0.9957 - val_f1_m: 0.9646
# Epoch 16/30
# 95/95 [==============================] - 103s 1s/step - loss: 0.0368 - accuracy: 0.9630 - auc: 0.9958 - f1_m: 0.9634 - val_loss: 0.0827 - val_accuracy: 0.9701 - val_auc: 0.9982 - val_f1_m: 0.9707
# Epoch 17/30
# 95/95 [==============================] - 104s 1s/step - loss: 0.0301 - accuracy: 0.9712 - auc: 0.9970 - f1_m: 0.9711 - val_loss: 0.1167 - val_accuracy: 0.9728 - val_auc: 0.9959 - val_f1_m: 0.9728
# Epoch 18/30
# 95/95 [==============================] - 102s 1s/step - loss: 0.0352 - accuracy: 0.9695 - auc: 0.9954 - f1_m: 0.9670 - val_loss: 0.1233 - val_accuracy: 0.9524 - val_auc: 0.9955 - val_f1_m: 0.9522
# Epoch 19/30
# 95/95 [==============================] - 99s 1s/step - loss: 0.0322 - accuracy: 0.9648 - auc: 0.9962 - f1_m: 0.9637 - val_loss: 0.1331 - val_accuracy: 0.9538 - val_auc: 0.9945 - val_f1_m: 0.9531
# Epoch 20/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0501 - accuracy: 0.9532 - auc: 0.9920 - f1_m: 0.9514 - val_loss: 0.1296 - val_accuracy: 0.9579 - val_auc: 0.9938 - val_f1_m: 0.9585
# Epoch 21/30
# 95/95 [==============================] - 97s 1s/step - loss: 0.0329 - accuracy: 0.9630 - auc: 0.9965 - f1_m: 0.9631 - val_loss: 0.1416 - val_accuracy: 0.9484 - val_auc: 0.9938 - val_f1_m: 0.9476
# Epoch 22/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0307 - accuracy: 0.9739 - auc: 0.9966 - f1_m: 0.9741 - val_loss: 0.1184 - val_accuracy: 0.9565 - val_auc: 0.9953 - val_f1_m: 0.9557
# Epoch 23/30
# 95/95 [==============================] - 99s 1s/step - loss: 0.0412 - accuracy: 0.9646 - auc: 0.9923 - f1_m: 0.9643 - val_loss: 0.0835 - val_accuracy: 0.9674 - val_auc: 0.9981 - val_f1_m: 0.9674
# Epoch 24/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0198 - accuracy: 0.9839 - auc: 0.9984 - f1_m: 0.9833 - val_loss: 0.1062 - val_accuracy: 0.9660 - val_auc: 0.9958 - val_f1_m: 0.9660
# Epoch 25/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0357 - accuracy: 0.9617 - auc: 0.9955 - f1_m: 0.9615 - val_loss: 0.0892 - val_accuracy: 0.9728 - val_auc: 0.9951 - val_f1_m: 0.9721
# Epoch 26/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0274 - accuracy: 0.9710 - auc: 0.9972 - f1_m: 0.9720 - val_loss: 0.1097 - val_accuracy: 0.9728 - val_auc: 0.9944 - val_f1_m: 0.9721
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 27/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0255 - accuracy: 0.9792 - auc: 0.9974 - f1_m: 0.9783 - val_loss: 0.0566 - val_accuracy: 0.9755 - val_auc: 0.9990 - val_f1_m: 0.9762
# Epoch 28/30
# 95/95 [==============================] - 97s 1s/step - loss: 0.0146 - accuracy: 0.9878 - auc: 0.9992 - f1_m: 0.9877 - val_loss: 0.0701 - val_accuracy: 0.9769 - val_auc: 0.9977 - val_f1_m: 0.9761
# Epoch 29/30
# 95/95 [==============================] - 98s 1s/step - loss: 0.0169 - accuracy: 0.9849 - auc: 0.9984 - f1_m: 0.9852 - val_loss: 0.0825 - val_accuracy: 0.9728 - val_auc: 0.9969 - val_f1_m: 0.9728
# Epoch 30/30
# 95/95 [==============================] - 97s 1s/step - loss: 0.0157 - accuracy: 0.9822 - auc: 0.9991 - f1_m: 0.9816 - val_loss: 0.0756 - val_accuracy: 0.9728 - val_auc: 0.9977 - val_f1_m: 0.9728

# %% [markdown]
# ## Evaluation of the fine-tuned model

# %%
fine_tuned_results = final_model.evaluate_generator(generator = test_generator, steps = df_test.shape[0] // batch_size)
for index, metric in enumerate(final_model.metrics_names):
  print(f'test_{metric} :',round(fine_tuned_results[index]*100),'%')
# Out:
# test_loss : 6 %
# test_accuracy : 98 %
# test_auc : 100 %
# test_f1_m : 98 %

# %%
display_history(finetuned_history)

# %% [markdown]
# ### Confusion matrix

# %%
test_generator.reset()
predictions = final_model.predict_generator(generator = test_generator)
y_test = test_generator.classes
y_pred = np.argmax(predictions, axis = -1)
class_names = test_generator.class_indices.keys()

# %%
fine_labels = (train_generator.class_indices)
fine_labels = dict((v,k) for k,v in fine_labels.items())
fine_final_predictions = [fine_labels[k] for k in y_pred]

filenames = test_generator.filenames
fine_results = pd.DataFrame({"img_paths":filenames,
                             "Predictions":fine_final_predictions})

# %%
fine_final_df_labels = df_test.merge(fine_results, on = 'img_paths')
fine_final_df_labels.head()
# Out:
#                                            img_paths     label Predictions
# 0  /content/drive/MyDrive/COVID-19 Radiography Da...     Viral       Viral
# 1  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19    COVID-19
# 2  /content/drive/MyDrive/COVID-19 Radiography Da...    NORMAL      NORMAL
# 3  /content/drive/MyDrive/COVID-19 Radiography Da...     Viral       Viral
# 4  /content/drive/MyDrive/COVID-19 Radiography Da...  COVID-19    COVID-19

# %%
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# %%
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, title = 'Normalized confusion matrix')
plt.show();

# %% [markdown]
# > We have a better recall for the Viral Pneumonia class (96%) than before tuning the model (91%).
# > The Normal class is perfect, 100% recall which means that all of the 'normal' images are perfectly identified.

# %% [markdown]
# ### Classification report

# %%
print(classification_report(y_test, y_pred, target_names = class_names))
# Out:
#               precision    recall  f1-score   support
#
#     COVID-19       0.99      1.00      1.00       229
#       NORMAL       0.96      0.97      0.96       268
#        Viral       0.97      0.96      0.97       269
#
#     accuracy                           0.97       766
#    macro avg       0.97      0.98      0.97       766
# weighted avg       0.97      0.97      0.97       766

# %%
# final_model.save('/content/drive/MyDrive/fine_tuned_vgg16_second_model.h5')

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Visualisation of the predictions

# %% [markdown]
# > We define a function `show_pred` that aims to plot as many images as we want with the predicted labels and the original labels as titles.

# %%
model = load_model('/content/drive/MyDrive/fine_tuned_vgg16_second_model.h5', custom_objects = {'f1_m' : f1_m})

# %%
labels = ['COVID-19', 'NORMAL', 'Viral Pneumonia']

# %%
def show_pred(path, row, col):
  # Create a matplotlib figure
  fig = plt.figure(figsize = (15, 12))
  ax = []

  size = (224, 224)

  # Browe files in the path directory
  listOfFiles = list()
  for (dirpath, dirnames, filenames) in os.walk(path):
    listOfFiles += [os.path.join(dirpath, file) for file in filenames]

  # Randomly select pictures from the path directory
  files = random.sample(range(len(listOfFiles)), col*row)

  for i in range(row*col):
    # pre-process the images
    img = load_img(listOfFiles[files[i]], target_size = size)
    img_array = img_to_array(img)

    if len(img_array.shape) == 3:
      normalized_img_array = (img_array.astype(np.float32)/255.)
      img_batch = np.expand_dims(normalized_img_array, axis=0)
    else:
      img_array = np.stack((img_array, )*3, axis = -1)
      normalized_img_array = (img_array.astype(np.float32)/255.)
      img_batch = np.expand_dims(normalized_img_array, axis=0)

    # Get predictions from the model
    prediction = model.predict(img_batch)

    # Get predicted label
    predicted_encoded_label = np.argmax(prediction)
    if predicted_encoded_label == 0:
      predicted_label = labels[0]
    elif predicted_encoded_label == 1:
      predicted_label = labels[1]
    else:
      predicted_label = labels[2]
    
    # Plot the results
    ax.append(fig.add_subplot(row, col, i+1))
    ax[-1].set_title('Predicted label : {}'.format(predicted_label) +
                     '\nGround truth : {}'.format(predicted_label))
    
    plt.axis('off')
    plt.tight_layout()
    plt.imshow(img)

# %%
show_pred('/content/drive/MyDrive/COVID-19 Radiography Database', 2, 5)

# %% [markdown]
# > All of the images are correctly classified.
